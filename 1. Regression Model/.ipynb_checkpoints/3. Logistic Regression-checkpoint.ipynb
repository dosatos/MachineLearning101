# %% [markdown]
# References: https://www.analyticsvidhya.com/blog/2015/08/comprehensive-guide-regression/

# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# Previously, we've seen how to use Linear Regression for Predictions

# %% [markdown]
# ## In this example we are going to work with the same dataset:
# __40 observations of people brain related indicators to predict if it belongs to a Male or Female.__ <br>
# Full Scale IQ (combines performance of the VCI, PRI, WMI, and PSI),<br>
# Verbal IQ (verbal comprehension and working memory),<br>
# Performance IQ (perceptual organization and processing speed) <br>
# Magnetic Resonance Imagine is used to determine the brain size of individuals.

# %%
file_name = 'brain_size.csv'
path = os.getcwd() + '/../Datasets/' + file_name
data = pd.read_csv(path, na_values=".")#, sep=';', na_values=".")
data.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0  Female   133  132  124   118.0    64.5     816932
# 1    Male   140  150  124     NaN    72.5    1001121
# 2    Male   139  123  150   143.0    73.3    1038437
# 3    Male   133  129  128   172.0    68.8     965353
# 4  Female   137  132  134   147.0    65.0     951545

# %%
data.Gender = data.Gender.astype('category')
data.Gender = data.Gender.cat.codes
male = data[data.Gender == 1]
female = data[data.Gender == 0]

male = male.fillna(male.mean())
female = female.fillna(female.mean())

data = pd.concat([male, female])
print(data.shape)
data.head()
# Out:
# (40, 7)
#    Gender  FSIQ  VIQ  PIQ      Weight  Height  MRI_Count
# 1       1   140  150  124  166.444444    72.5    1001121
# 2       1   139  123  150  143.000000    73.3    1038437
# 3       1   133  129  128  172.000000    68.8     965353
# 8       1    89   93   84  134.000000    66.3     904858
# 9       1   133  114  147  172.000000    68.8     955466

# %% [markdown]
# ### Let's apply Logistic Regression Model

# %% [markdown]
# Let's recall what our data looks like <br>
# (I skip plotting the non-representative features) <br>

# %%
cols = ['Gender', 'Weight', 'MRI_Count', 'Height']
df = data[cols]

graph = sns.pairplot(df, markers=[".", 'x'],
                     hue='Gender')

# %% [markdown]
# Now lets see how Logistic Regression Looks like within our dataset context

# %%
cols = ['Gender', 'Weight', 'MRI_Count', 'Height']
df = data[cols]

plt.figure(figsize=(15, 5))

for idx, col in enumerate(['Weight', 'MRI_Count', 'Height']):
    plt.ylim(0,1)
    plt.subplot('13{}'.format(idx+1))
    sns.regplot(x=col, y="Gender", data=df, logistic=True)
# Out:
# /Users/yeldosbalgabekov/anaconda2/envs/py35/lib/python3.6/site-packages/statsmodels/genmod/families/links.py:168: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)

# %% [markdown]
# On the above figures we can see a Logistic Regression model behaviour. So we can use "above/below" thresholds for decision making.

# %% [markdown]
# It differs from Linear Models by its curviness as well as bottom and top caps, which makes it more suitable for our case.

# %% [markdown]
# Let's split the data into training and testing sets

# %%
cols = ['Gender', 'Weight', 'MRI_Count', 'Height']
df = data[cols]

accs = []

# lets take the average accuracy of 500 iterations
for i in range(500):
    train, test = train_test_split(df, test_size=0.2)
    x_train, y_train = train.iloc[:, 1:], train.iloc[:, 0]
    x_test, y_test = test.iloc[:, 1:], test.iloc[:, 0]

    # Use sklearn's Linear Regression model
    model = LogisticRegression()
    model.fit(x_train, y_train)
    prediction = model.predict(x_test)
    prediction = [1 if label >= 0.5 else 0 for label in prediction]
    acc = sum(prediction == y_test)/len(y_test)*100
    accs.append(acc)
res = sum(accs) / len(accs)
print("Average Accuracy: {}%".format(res))
# Out:
# Average Accuracy: 56.125%

# %% [markdown]
# ### Let's Check if there is a difference using one, two, three features

# %%
df = data[['Gender', 'Weight', 'MRI_Count', 'Height']]
accs = {i: [] for i in range(7)}
scenarios = [['Weight', 'MRI_Count', 'Height'], 
                ['Weight', 'MRI_Count'], 
                ['Weight', 'Height'], 
                ['MRI_Count', 'Height'], 
                ['Weight'], 
                ['MRI_Count'], 
                ['Height']]

for i in range(500):
    train, test = train_test_split(df, test_size=0.2)
    for idx, cols in enumerate(scenarios):
        
        # the average accuracy of 100 iterations
        x_train, y_train = train[cols], train['Gender']
        x_test, y_test = test[cols], test['Gender']

        # Use sklearn's Linear Regression model
        model = LogisticRegression()
        model.fit(x_train, y_train)
        prediction = model.predict(x_test)
        prediction = [1 if label >= 0.5 else 0 for label in prediction]
        
        acc = sum(prediction == y_test)/len(y_test)*100
        accs[idx].append(acc)

# %%
accs1 = pd.DataFrame.from_dict(accs)
for idx, cols in enumerate(scenarios):
    print(idx, cols)
accs1.describe()
# Out:
# 0 ['Weight', 'MRI_Count', 'Height']
# 1 ['Weight', 'MRI_Count']
# 2 ['Weight', 'Height']
# 3 ['MRI_Count', 'Height']
# 4 ['Weight']
# 5 ['MRI_Count']
# 6 ['Height']
#                 0           1          2           3           4           5  \
# count  500.000000  500.000000  500.00000  500.000000  500.000000  500.000000
# mean    57.450000   56.625000   69.27500   40.000000   60.300000   38.025000
# std     18.780386   18.664635   14.93261   11.817542   18.050253    9.949113
# min     12.500000   12.500000   25.00000   12.500000   12.500000   12.500000
# 25%     50.000000   50.000000   62.50000   37.500000   50.000000   37.500000
# 50%     62.500000   62.500000   75.00000   37.500000   62.500000   37.500000
# 75%     75.000000   75.000000   75.00000   50.000000   75.000000   50.000000
# max    100.000000  100.000000  100.00000   75.000000  100.000000   62.500000
#
#                 6
# count  500.000000
# mean    41.375000
# std     12.423992
# min     12.500000
# ...

# %% [markdown]
# So we can see that the highest result shows Weight + Height features, with std 11.22

# %% [markdown]
# ### Can we improve the results even higher

# %% [markdown]
# We can see that Weight ranges from min 106 to max 192, and Height from min 62 to max 77. <br>

# %% [markdown]
# Let's normalise the data (min max scaler)

# %%
df = (df - df.min()) / (df.max()-df.min())
df.describe()
# Out:
#          Gender     Weight  MRI_Count     Height
# count  40.00000  40.000000  40.000000  40.000000
# mean    0.50000   0.532817   0.408874   0.439886
# std     0.50637   0.268832   0.250171   0.264652
# min     0.00000   0.000000   0.000000   0.000000
# 25%     0.00000   0.345930   0.226005   0.266667
# 50%     0.50000   0.482558   0.397259   0.416667
# 75%     1.00000   0.767442   0.551895   0.582193
# max     1.00000   1.000000   1.000000   1.000000

# %%
df = data[['Gender', 'Weight', 'MRI_Count', 'Height']]
df = (df - df.min()) / (df.max()-df.min())
accs = {i: [] for i in range(7)}
scenarios = [['Weight', 'MRI_Count', 'Height'], 
                ['Weight', 'MRI_Count'], 
                ['Weight', 'Height'], 
                ['MRI_Count', 'Height'], 
                ['Weight'], 
                ['MRI_Count'], 
                ['Height']]

for i in range(500):
    train, test = train_test_split(df, test_size=0.2)
    for idx, cols in enumerate(scenarios):
        
        # the average accuracy of 100 iterations
        x_train, y_train = train[cols], train['Gender']
        x_test, y_test = test[cols], test['Gender']

        # Use sklearn's Linear Regression model
        model = LogisticRegression()
        model.fit(x_train, y_train)
        prediction = model.predict(x_test)
        prediction = [1 if label >= 0.5 else 0 for label in prediction]
        
        acc = sum(prediction == y_test)/len(y_test)*100
        accs[idx].append(acc)

# %%
accs2 = pd.DataFrame.from_dict(accs)
for idx, cols in enumerate(scenarios):
    print(idx, cols)
accs2.describe()
# Out:
# 0 ['Weight', 'MRI_Count', 'Height']
# 1 ['Weight', 'MRI_Count']
# 2 ['Weight', 'Height']
# 3 ['MRI_Count', 'Height']
# 4 ['Weight']
# 5 ['MRI_Count']
# 6 ['Height']
#                 0           1          2           3           4           5  \
# count  500.000000  500.000000  500.00000  500.000000  500.000000  500.000000
# mean    81.025000   77.100000   80.50000   82.725000   70.675000   76.625000
# std     13.852641   14.265237   15.29601   12.882888   16.515975   15.020756
# min     25.000000   25.000000   12.50000   37.500000   25.000000   12.500000
# 25%     75.000000   62.500000   75.00000   75.000000   62.500000   62.500000
# 50%     87.500000   75.000000   87.50000   87.500000   75.000000   75.000000
# 75%     87.500000   87.500000   87.50000   87.500000   87.500000   87.500000
# max    100.000000  100.000000  100.00000  100.000000  100.000000  100.000000
#
#                 6
# count  500.000000
# mean    79.750000
# std     14.654077
# min     25.000000
# ...

# %% [markdown]
# The prediction rate not significantly changed

# %%
normalised = (data - data.min()) / (data.max() - data.min())
normalised.head()
sns.heatmap(normalised.corr(), annot=True)

# %%
plt.plot(normalised.Gender, normalised.Weight, '.')

# %%
# model = ols("Gender ~ Weight", normalised).fit()
# model.summary()

# %%
def logistic_prediction(df, independent_cols):
    clf = LogisticRegression(penalty='l2')
    # print('Gender: {}, Weight: {}'.format(int(df.Gender[0]), df.Weight[0]))
    result = clf.fit(df[independent_cols], df['Gender'])
    return sum(df.Gender==result.predict(df[independent_cols].values.reshape(-1, len(independent_cols))))/len(df.Gender)

for independent_cols in [['Weight', 'Height', 'MRI_Count'], ['Weight', 'MRI_Count'], ['Height', 'MRI_Count'], ['Weight', 'Height'], ['Weight'], ['MRI_Count'], ['Height']]:
    print('\n====== {} ======'.format(independent_cols))
    print('normalised:', logistic_prediction(normalised, independent_cols))
    print('unnormalised:', logistic_prediction(data, independent_cols))
# Out:
# ====== ['Weight', 'Height', 'MRI_Count'] ======
# normalised: 0.9
# unnormalised: 0.675
#
# ====== ['Weight', 'MRI_Count'] ======
# normalised: 0.825
# unnormalised: 0.675
#
# ====== ['Height', 'MRI_Count'] ======
# normalised: 0.875
# unnormalised: 0.5
#
# ====== ['Weight', 'Height'] ======
# normalised: 0.85
# unnormalised: 0.7
#
# ====== ['Weight'] ======
# normalised: 0.8
# unnormalised: 0.675
#
# ====== ['MRI_Count'] ======
# normalised: 0.825
# unnormalised: 0.5
#
# ====== ['Height'] ======
# normalised: 0.825
# unnormalised: 0.525

# %%
def linear_prediction(df, independent_cols):
    clf = LinearRegression()
    # print('Gender: {}, Weight: {}'.format(int(df.Gender[0]), df.Weight[0]))
    result = clf.fit(df[independent_cols], df['Gender'])
    return sum(df.Gender==result.predict(df[independent_cols].values.reshape(-1, len(independent_cols))))/len(df.Gender)

for independent_cols in [['Weight', 'Height', 'MRI_Count'], ['Weight', 'MRI_Count'], ['Height', 'MRI_Count'], ['Weight', 'Height'], ['Weight'], ['MRI_Count'], ['Height']]:
    print('\n====== {} ======'.format(independent_cols))
    print('normalised:', linear_prediction(normalised, independent_cols))
    print('unnormalised:', linear_prediction(data, independent_cols))
# Out:
# ====== ['Weight', 'Height', 'MRI_Count'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Weight', 'MRI_Count'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Height', 'MRI_Count'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Weight', 'Height'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Weight'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['MRI_Count'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Height'] ======
# normalised: 0.0
# unnormalised: 0.0

# %%
def lasso_prediction(df, independent_cols):
    clf = Lasso()
    # print('Gender: {}, Weight: {}'.format(int(df.Gender[0]), df.Weight[0]))
    result = clf.fit(df[independent_cols], df['Gender'])
    return sum(df.Gender==result.predict(df[independent_cols].values.reshape(-1, len(independent_cols))))/len(df.Gender)

for independent_cols in [['Weight', 'Height', 'MRI_Count'], ['Weight', 'MRI_Count'], ['Height', 'MRI_Count'], ['Weight', 'Height'], ['Weight'], ['MRI_Count'], ['Height']]:
    print('\n====== {} ======'.format(independent_cols))
    print('normalised:', lasso_prediction(normalised, independent_cols))
    print('unnormalised:', lasso_prediction(data, independent_cols))
# Out:
# ====== ['Weight', 'Height', 'MRI_Count'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Weight', 'MRI_Count'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Height', 'MRI_Count'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Weight', 'Height'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Weight'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['MRI_Count'] ======
# normalised: 0.0
# unnormalised: 0.0
#
# ====== ['Height'] ======
# normalised: 0.0
# unnormalised: 0.0

# %%
def svc_prediction(df, independent_cols):
    clf = SVC(kernel='rbf')
    # print('Gender: {}, Weight: {}'.format(int(df.Gender[0]), df.Weight[0]))
    result = clf.fit(df[independent_cols], df['Gender'])
    return sum(df.Gender==result.predict(df[independent_cols].values.reshape(-1, len(independent_cols))))/len(df.Gender)

for independent_cols in [['Weight', 'Height', 'MRI_Count'], ['Weight', 'MRI_Count'], ['Height', 'MRI_Count'], ['Weight', 'Height'], ['Weight'], ['MRI_Count'], ['Height']]:
    print('\n====== {} ======'.format(independent_cols))
    print('normalised:', svc_prediction(normalised, independent_cols))
    print('unnormalised:', svc_prediction(data, independent_cols))
# Out:
# ====== ['Weight', 'Height', 'MRI_Count'] ======
# normalised: 0.9
# unnormalised: 1.0
#
# ====== ['Weight', 'MRI_Count'] ======
# normalised: 0.825
# unnormalised: 1.0
#
# ====== ['Height', 'MRI_Count'] ======
# normalised: 0.9
# unnormalised: 1.0
#
# ====== ['Weight', 'Height'] ======
# normalised: 0.9
# unnormalised: 1.0
#
# ====== ['Weight'] ======
# normalised: 0.775
# unnormalised: 0.95
#
# ====== ['MRI_Count'] ======
# normalised: 0.825
# unnormalised: 1.0
#
# ====== ['Height'] ======
# normalised: 0.85
# unnormalised: 0.85

# %%
plt.plot(data['Weight'], data.Gender, '.')

# %%
data[data.Gender == 1].shape, data[data.Gender == 0].shape
# Out:
# ((20, 7), (20, 7))

# %%
tmp = normalised[['Weight', 'Gender']]
l = 0
tmp['RBF'] = np.exp(-(tmp.Weight - l) / (2 * tmp.Weight.var() ** 0.5) )
tmp = tmp[['Weight', 'RBF', 'Gender']]
# plt.plot(tmp['Weight'], tmp['RBF'], '.')
sns.pairplot(tmp, hue='Gender')
# Out:
# /Users/yeldosbalgabekov/anaconda2/envs/py35/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def svc_test(df):
    clf = SVC()
    size = 30
    trainX, testX = df.iloc[:size, 4:], df.iloc[size:, 4:]
    trainY, testY = df.iloc[:size, 0], df.iloc[size:, 0]
    model = clf.fit(trainX, trainY)
    pred = model.predict(testX)
    print(sum(pred==testY)/len(pred))

print(svc_test(normalised), svc_test(data))
# Out:
# 0.8
# 0.0
# None None

# %%
def classify(df, clf1):
    clf = clf1()
    size = 30
    trainX, testX = df.iloc[:size, 4:], df.iloc[size:, 4:]
    trainY, testY = df.iloc[:size, 0], df.iloc[size:, 0]
    model = clf.fit(trainX, trainY)
    pred = model.predict(testX)
    print(sum(pred==testY)/len(pred))

names = ['LogisticRegression', 'LinearRegression', 'Lasso', 'SVC']
for idx, c in enumerate([LogisticRegression, LinearRegression, Lasso, SVC]):
    print(names[idx], ':')
    classify(normalised, c)
    classify(data, c)
# Out:
# LogisticRegression :
# 0.4
# 0.0
# LinearRegression :
# 0.0
# 0.0
# Lasso :
# 0.0
# 0.0
# SVC :
# 0.8
# 0.0

# %%
from mpl_toolkits.mplot3d import Axes3D

size = 30
tmp = normalised.iloc[:30]
tmp = tmp[['Gender', 'Weight', 'Height', 'MRI_Count']]
tmp1 = tmp[tmp.Gender == 1]
tmp2 = tmp[tmp.Gender == 0]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for c, m, tmpdf in [('r', 'o', tmp1), ('b', '^', tmp2)]:
    ax.scatter(
                tmpdf.iloc[0:, 1], 
                tmpdf.iloc[0:, 2], 
                tmpdf.iloc[0:, 3], 
                c=c, 
                marker=m
    )

# %%
data_tmp = data.iloc[:30]
data_tmp = data_tmp[['Gender', 'Weight', 'Height', 'MRI_Count']]
sns.pairplot(hue='Gender', data=data_tmp)
# Out:
# ----------------------------------------------------------------------
# AttributeError                       Traceback (most recent call last)
# <ipython-input-58-a1f2c6b859c7> in <module>()
# ----> 1 data_tmp = data.iloc[:30]
#       2 data_tmp = data_tmp[['Gender', 'Weight', 'Height', 'MRI_Count']]
#       3 sns.pairplot(hue='Gender', data=data_tmp)
#
# AttributeError: 'list' object has no attribute 'iloc'

# %%
tmp = normalised.iloc[:30]
tmp = tmp[['Gender', 'Weight', 'Height', 'MRI_Count']]
sns.pairplot(hue='Gender', data=tmp)
